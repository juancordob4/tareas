# %% [markdown]
# <a href="https://colab.research.google.com/github/juancordob4/tareas/blob/main/listapython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicios python

# %% [markdown]
# Cordial saludo, a continuacion vamos a realizar una lista de ejercicos basicos en python.

# %% [markdown]
# 1. Crear una llista llamada frutas que contenga los siguientes valores "apple", "banana", "orange", and
# "grape". Imprimir la lista

# %%
fruits = ["apple", "banana", "orange", "grape"]
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'grape']

# %% [markdown]
# 2. Le damos una lista de numeros y mostramos el primer elemento.

# %%
numbers= [4,8,15,16,23,42]
print(numbers[0])
# Out:
# 4

# %% [markdown]
# 3. Le damos una nueva lista y mostramos el ultimo numero de la lista.

# %%
numbers= [4,8,15,16,23,42]
print(numbers[-1])
# Out:
# 42

# %% [markdown]
# 4. Le damos una lista de colores y mostramos el 2 y 3 elemento

# %%
colors = ["red", "blue","green" , "yellow"]
print(colors[1:3])
# Out:
# ['blue', 'green']

# %% [markdown]
# 5. Creamos una lista con 5 ciudades y mostramos el numero de elementos en la lista

# %%
city =["Bogota","Tunja","Monteria","Santa Marta","Cartagena"]
print(len(city))
# Out:
# 5

# %% [markdown]
# 6. Le damos una lista y agregamos hamster al final de la lista y mostramos la lista actualizada.

# %%
animals = ["dog", "cat", "rabbit"]
animals.append("hamster")
print(animals)
# Out:
# ['dog', 'cat', 'rabbit', 'hamster']

# %% [markdown]
# 7. Le damos una lista y insertamos bird en la segunda posicion de la lista y la actualizamos.

# %%
animals = ["dog", "cat", "rabbit"]
animals.insert(1, "bird")
print(animals)
# Out:
# ['dog', 'bird', 'cat', 'rabbit']

# %% [markdown]
# 8. Le damos una lista y removemos el valor 30 de la lista y la actualizamos.

# %%
numbers = [10, 20, 30, 40, 50]
numbers.remove(30)
print(numbers)
# Out:
# [10, 20, 40, 50]

# %% [markdown]
# 9. Le damos una lista y removemos el ultimo elemento con la funcion de pop()

# %%
letters = ["a", "b", "c", "d", "e"]
letters.pop()
print(letters)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# 10. Le damos una lista y miramos si maria esta en la lista con true o false

# %%
names = ["Ana", "Luis", "Maria", "Pedro"]
print("Maria" in names)
# Out:
# True

# %% [markdown]
# 11. Organizamos la lista en orden ascendente y observamos el resultado

# %%
numbers = [5, 2, 9, 1, 7]
numbers.sort()
print(numbers)
# Out:
# [1, 2, 5, 7, 9]

# %% [markdown]
# 12. Ahoora odernamos la lista en orden descendente y observamos el resultado

# %%
numbers = [5, 2, 9, 1, 7]
numbers.sort(reverse=True)
print(numbers)
# Out:
# [9, 7, 5, 2, 1]

# %% [markdown]
# 13. Miramos esta lista y creamos una nueva_lista en donde cada valor es numbers pero *2

# %%
numbers = [3, 6, 9, 12, 15]
nueva_lista = [numero * 2 for numero in numbers]
print(nueva_lista)
# Out:
# [6, 12, 18, 24, 30]

# %% [markdown]
# 14. Usamos un loop para mostrar cada palabra en una lineas

# %%
words = ["python", "list", "exercise", "practice"]
for palabra in words:
    print(palabra)
# Out:
# python
# list
# exercise
# practice

# %% [markdown]
# 15. Calculamos el promedio de la nota

# %%
grades = [80, 75, 90, 85, 95]
promedio = sum(grades) / len(grades)
print(promedio)
# Out:
# 85.0

# %% [markdown]
# <a href="https://colab.research.google.com/github/juancordob4/tareas/blob/main/Diccionario.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # En primer lugar vamos a realizar el ejercicio 1

# %%
# Ejercicio 1
student = {"name": "Juan","age":17,"grade":"A"}
print(student)
# Out:
# {'name': 'Juan', 'age': 17, 'grade': 'A'}

# %% [markdown]
# Ahora el ejercicio 2 (Vamos acceder a Brand)

# %%
car = {"brand": "Toyota", "model": "Corolla", "year": 2020}
print(car["brand"])
# Out:
# Toyota

# %% [markdown]
# Ahora el ejercicio 3 (Observaremos el año)

# %%
car = {"brand": "Toyota", "model": "Corolla", "year": 2020}
print(car["year"])
# Out:
# 2020

# %% [markdown]
# El ejercicio 4 nos pide copiar la llave y añadir una nueva llave denominada city

# %%
person = {"name": "Alice", "age": 25}
person["city"] = "Bogota"
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Bogota'}

# %% [markdown]
# El ejercicio 5, le damos esta linea al diccionario y cambiamos el valor de age a "26"

# %%
person = {"name": "Alice", "age": 25, "city": "Bogota"}
person["age"] = 26
print(person)
# Out:
# {'name': 'Alice', 'age': 26, 'city': 'Bogota'}

# %% [markdown]
# En el numero 6, le damos esto al diccionario y eliminamos la ciudad

# %%
person = {"name": "Alice", "age": 25, "city": "Bogota"}
del person["city"]
print(person)
# Out:
# {'name': 'Alice', 'age': 25}

# %% [markdown]
# En el 7 le damos esto al diccionario y mostramos todas las llaves

# %%
fruits = {"apple": 3, "banana": 5, "orange": 2}
print(fruits.keys())
# Out:
# dict_keys(['apple', 'banana', 'orange'])

# %% [markdown]
# En el 8 vamos a mostrar todos los valores

# %%
fruits = {"apple": 3, "banana": 5, "orange": 2}
print(fruits)
# Out:
# {'apple': 3, 'banana': 5, 'orange': 2}

# %% [markdown]
# En el 9 vamos a crear reccores los valores y claves

# %%
fruits = {"apple": 3, "banana": 5, "orange": 2}
for key, value in fruits.items():
    print(key, value)
# Out:
# apple 3
# banana 5
# orange 2

# %% [markdown]
# En el 10, le damos una nueva llave al diccionario, Mirar si Luis existe o no en el diccionario. Imprimiendo si es falso o verdadero.

# %%
grades = {"Ana": 85, "Luis": 90, "Maria": 78}

print("Luis" in grades)
# Out:
# True

# %% [markdown]
# En el 11, realizaremos lo mismo pero con Pedro

# %%
grades = {"Ana": 85, "Luis": 90, "Maria": 78}

print("Pedro" in grades)
# Out:
# False

# %% [markdown]
# En el 12, calculamos e imprimimos la suma de todos los valores del diccionario.

# %%
numbers = {"a": 10, "b": 20, "c": 30}
print(sum(numbers.values()))
# Out:
# 60

# %% [markdown]
# En el 13, imprimimos el valor del numero del valor de la llave en el diccionario.

# %%
inventory = {"pens": 10, "notebooks": 5, "erasers": 8}
print(len(inventory))
# Out:
# 3

# %% [markdown]
# En el 14, Hallaremos cada pais con su capital con "Loop"

# %%
countries = {"Colombia": "Bogota", "France": "Paris", "Japan": "Tokyo"}
for country, capital in countries.items():
    print(f"La capital de {country} es {capital}")
# Out:
# La capital de Colombia es Bogota
# La capital de France es Paris
# La capital de Japan es Tokyo

# %% [markdown]
# Finalmente en el numero 15, hallaremos el dai con la mayor temperatura en el diccionario.

# %%
temperatures = {"Monday": 22, "Tuesday": 24, "Wednesday": 21, "Thursday": 23}
print(max(temperatures.values()))
# Out:
# 24
